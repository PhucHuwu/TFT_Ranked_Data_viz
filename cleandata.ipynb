# %% [markdown]
# # Chuẩn Hóa và Làm Sạch Dữ Liệu TFT Leaderboard
#
# 1. Kiểm tra kiểu dữ liệu
# 2. Xử lý giá trị thiếu (missing values)
# 3. Chuẩn hóa kiểu dữ liệu
# 4. Lưu dữ liệu đã làm sạch

# %%
import pandas as pd
import numpy as np
import json
import warnings
warnings.filterwarnings('ignore')

# %%
# Load dữ liệu CSV
df = pd.read_csv('data/leaderboard.csv')

print(f"Số dòng: {len(df)}")
print(f"Số cột: {len(df.columns)}")
print(f"Kích thước: {df.shape}")
df.head()
# Out:
# Số dòng: 1000
# Số cột: 41
# Kích thước: (1000, 41)
#    rank  rating_numeric  num_played  player_id summoner_region  \
# 0     1            4872         561  353582905             me1
# 1     2            4871         477    3941714             br1
# 2     3            4737         507    1696341            eun1
# 3     4            4735         477  450383412             sg2
# 4     5            4670         688    3322631             la2
#
#           riot_id                                              puuid  \
# 0       منجة#بحبك  SBM-65J8LDsup6NqXNrraEppoDoHt_QkPlA2qicbM_wQhT...
# 1   KBM Toddy#tft  nx9yc2rDqX_Rc7xwa7hJXeLZSQ5vCK6xMo9E8jDA9KQN1G...
# 2      Litiq#EUNE  h-oGE9-A_UbLbAn4r2Mhw0RST6V2otlLfuMihFFRXsyEOa...
# 3     FuuTime#xdd  dfFZTGk0bBYppTBlPNMvwrfsLwpsJF9vgl53-jjWxG4Kjm...
# 4  BlackSheep#Rap  NiJyBETk-4MDyXRA7qWaK-mPTVeAIdEOQkHr8nH7ywb__m...
#
#                  rating live.encryption_key  live.game_start_time  ...  \
# 0  CHALLENGER I 2072 LP                 NaN                   NaN  ...
# 1  CHALLENGER I 2071 LP                 NaN                   NaN  ...
# 2  CHALLENGER I 1937 LP                 NaN                   NaN  ...
# 3  CHALLENGER I 1935 LP                 NaN                   NaN  ...
# 4  CHALLENGER I 1870 LP                 NaN                   NaN  ...
#
#   stats.currentPatchResult.damage_percentile_sum  \
# 0                                         1339.0
# 1                                            NaN
# 2                                            3.0
# 3                                          290.0
# 4                                            NaN
#
#    stats.currentPatchResult.lpChange stats.currentPatchResult.num_played  \
# 0                              280.0                                22.0
# 1                                NaN                                 NaN
# 2                               10.0                                 1.0
# 3                               83.0                                 8.0
# 4                                NaN                                 NaN
#
#    stats.currentPatchResult.percentile_count  \
# 0                                       22.0
# 1                                        NaN
# 2                                        1.0
# 3                                        8.0
# 4                                        NaN
#
#    stats.currentPatchResult.place_sum  \
# 0                                55.0
# 1                                 NaN
# 2                                 4.0
# 3                                22.0
# 4                                 NaN
#
#                  stats.currentPatchResult.topCarries  \
# 0                                                 []
# 1                                                NaN
# 2  [{"character_id": "TFT15_Samira", "count": 1, ...
# 3                                                 []
# 4                                                NaN
#
#    stats.currentPatchResult.wins  stats.num_played  stats.place_sum  \
# 0                            9.0               561             1983
# 1                            NaN               477             1576
# 2                            0.0               506             1732
# 3                            2.0               477             1711
# 4                            NaN               687             2206
#
#    stats.wins
# 0         109
# 1         120
# 2         119
# 3         121
# 4         211
#
# [5 rows x 41 columns]

# %%
# Kiểm tra kiểu dữ liệu
print("=== KIỂU DỮ LIỆU CÁC CỘT ===")
print(df.dtypes)
print("\n" + "="*60)

# Thông tin tổng quan
print("\n=== THÔNG TIN TỔNG QUAN ===")
df.info()
# Out:
# === KIỂU DỮ LIỆU CÁC CỘT ===
# rank                                                        int64
# rating_numeric                                              int64
# num_played                                                  int64
# player_id                                                   int64
# summoner_region                                            object
# riot_id                                                    object
# puuid                                                      object
# rating                                                     object
# live.encryption_key                                        object
# live.game_start_time                                      float64
# live.match_id                                              object
# live.player_id                                            float64
# live.type                                                  object
# stats.RecentResult.ItemData.AD                              int64
# stats.RecentResult.ItemData.AP                              int64
# stats.RecentResult.ItemData.Tank                            int64
# stats.RecentResult.avg_similarity                         float64
# stats.RecentResult.board_strength_percentile_sum            int64
# stats.RecentResult.damage_percentile_sum                    int64
# stats.RecentResult.lpChange                                 int64
# stats.RecentResult.num_played                               int64
# stats.RecentResult.percentile_count                         int64
# stats.RecentResult.place_sum                                int64
# stats.RecentResult.topCarries                              object
# stats.RecentResult.wins                                     int64
# stats.appMatches                                             bool
# stats.currentPatchResult.ItemData.AD                      float64
# stats.currentPatchResult.ItemData.AP                      float64
# stats.currentPatchResult.ItemData.Tank                    float64
# stats.currentPatchResult.avg_similarity                   float64
# stats.currentPatchResult.board_strength_percentile_sum    float64
# stats.currentPatchResult.damage_percentile_sum            float64
# stats.currentPatchResult.lpChange                         float64
# stats.currentPatchResult.num_played                       float64
# stats.currentPatchResult.percentile_count                 float64
# stats.currentPatchResult.place_sum                        float64
# stats.currentPatchResult.topCarries                        object
# stats.currentPatchResult.wins                             float64
# stats.num_played                                            int64
# stats.place_sum                                             int64
# stats.wins                                                  int64
# dtype: object
#
# ============================================================
#
# === THÔNG TIN TỔNG QUAN ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   rank                                                    1000 non-null   int64
#  1   rating_numeric                                          1000 non-null   int64
#  2   num_played                                              1000 non-null   int64
#  3   player_id                                               1000 non-null   int64
#  4   summoner_region                                         1000 non-null   object
#  5   riot_id                                                 1000 non-null   object
#  6   puuid                                                   1000 non-null   object
#  7   rating                                                  1000 non-null   object
#  8   live.encryption_key                                     45 non-null     object
#  9   live.game_start_time                                    45 non-null     float64
#  10  live.match_id                                           45 non-null     object
#  11  live.player_id                                          45 non-null     float64
#  12  live.type                                               45 non-null     object
#  13  stats.RecentResult.ItemData.AD                          1000 non-null   int64
#  14  stats.RecentResult.ItemData.AP                          1000 non-null   int64
#  15  stats.RecentResult.ItemData.Tank                        1000 non-null   int64
#  16  stats.RecentResult.avg_similarity                       991 non-null    float64
#  17  stats.RecentResult.board_strength_percentile_sum        1000 non-null   int64
#  18  stats.RecentResult.damage_percentile_sum                1000 non-null   int64
#  19  stats.RecentResult.lpChange                             1000 non-null   int64
#  20  stats.RecentResult.num_played                           1000 non-null   int64
#  21  stats.RecentResult.percentile_count                     1000 non-null   int64
#  22  stats.RecentResult.place_sum                            1000 non-null   int64
#  23  stats.RecentResult.topCarries                           1000 non-null   object
#  24  stats.RecentResult.wins                                 1000 non-null   int64
#  25  stats.appMatches                                        1000 non-null   bool
#  26  stats.currentPatchResult.ItemData.AD                    376 non-null    float64
#  27  stats.currentPatchResult.ItemData.AP                    376 non-null    float64
#  28  stats.currentPatchResult.ItemData.Tank                  376 non-null    float64
#  29  stats.currentPatchResult.avg_similarity                 376 non-null    float64
#  30  stats.currentPatchResult.board_strength_percentile_sum  376 non-null    float64
#  31  stats.currentPatchResult.damage_percentile_sum          376 non-null    float64
#  32  stats.currentPatchResult.lpChange                       376 non-null    float64
#  33  stats.currentPatchResult.num_played                     376 non-null    float64
#  34  stats.currentPatchResult.percentile_count               376 non-null    float64
#  35  stats.currentPatchResult.place_sum                      376 non-null    float64
#  36  stats.currentPatchResult.topCarries                     376 non-null    object
#  37  stats.currentPatchResult.wins                           376 non-null    float64
#  38  stats.num_played                                        1000 non-null   int64
#  39  stats.place_sum                                         1000 non-null   int64
#  40  stats.wins                                              1000 non-null   int64
# dtypes: bool(1), float64(14), int64(17), object(9)
# memory usage: 313.6+ KB

# %%
# Kiểm tra số lượng giá trị thiếu
missing_values = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Tạo DataFrame để hiển thị
missing_df = pd.DataFrame({
    'Cột': missing_values.index,
    'Số lượng thiếu': missing_values.values,
    'Tỷ lệ (%)': missing_percentage.values
})

# Chỉ hiển thị các cột có giá trị thiếu
missing_df = missing_df[missing_df['Số lượng thiếu'] > 0].sort_values('Số lượng thiếu', ascending=False)

print("=== CÁC CỘT CÓ GIÁ TRỊ THIẾU ===")
if len(missing_df) > 0:
    print(missing_df.to_string(index=False))
else:
    print("Không có giá trị thiếu!")
    
print(f"\n\nTổng số cột có giá trị thiếu: {len(missing_df)}/{len(df.columns)}")
# Out:
# === CÁC CỘT CÓ GIÁ TRỊ THIẾU ===
#                                                    Cột  Số lượng thiếu  Tỷ lệ (%)
#                                    live.encryption_key             955       95.5
#                                   live.game_start_time             955       95.5
#                                          live.match_id             955       95.5
#                                         live.player_id             955       95.5
#                                              live.type             955       95.5
#                   stats.currentPatchResult.ItemData.AD             624       62.4
#                 stats.currentPatchResult.ItemData.Tank             624       62.4
#                   stats.currentPatchResult.ItemData.AP             624       62.4
#                stats.currentPatchResult.avg_similarity             624       62.4
# stats.currentPatchResult.board_strength_percentile_sum             624       62.4
#              stats.currentPatchResult.percentile_count             624       62.4
#         stats.currentPatchResult.damage_percentile_sum             624       62.4
#                      stats.currentPatchResult.lpChange             624       62.4
#                    stats.currentPatchResult.num_played             624       62.4
#                    stats.currentPatchResult.topCarries             624       62.4
#                     stats.currentPatchResult.place_sum             624       62.4
#                          stats.currentPatchResult.wins             624       62.4
#                      stats.RecentResult.avg_similarity               9        0.9
#
#
# Tổng số cột có giá trị thiếu: 18/41

# %%
# Tạo bản sao để làm việc
df_clean = df.copy()

# Đảm bảo các cột số nguyên
integer_columns = ['rank', 'rating_numeric', 'num_played', 'player_id']
for col in integer_columns:
    if col in df_clean.columns:
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce').fillna(0).astype('int64')

# Chuẩn hóa các cột chuỗi
string_columns = ['summoner_region', 'riot_id', 'puuid', 'rating']
for col in string_columns:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype(str)

# Chuẩn hóa các cột số thực cho stats
float_columns = [col for col in df_clean.columns if any(x in col for x in ['avg_similarity', 'percentile', 'lpChange'])]
for col in float_columns:
    df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

# Chuẩn hóa các cột số nguyên cho stats
stats_int_columns = [col for col in df_clean.columns if any(x in col for x in ['ItemData', 'num_played', 'place_sum', 'wins', 'percentile_count'])]
for col in stats_int_columns:
    if col not in integer_columns:  # Tránh xử lý lại
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce').fillna(0).astype('int64')

print("✓ Đã chuẩn hóa kiểu dữ liệu")
print(f"\nKiểu dữ liệu sau khi chuẩn hóa:")
print(df_clean.dtypes)
# Out:
# ✓ Đã chuẩn hóa kiểu dữ liệu
#
# Kiểu dữ liệu sau khi chuẩn hóa:
# rank                                                        int64
# rating_numeric                                              int64
# num_played                                                  int64
# player_id                                                   int64
# summoner_region                                            object
# riot_id                                                    object
# puuid                                                      object
# rating                                                     object
# live.encryption_key                                        object
# live.game_start_time                                      float64
# live.match_id                                              object
# live.player_id                                            float64
# live.type                                                  object
# stats.RecentResult.ItemData.AD                              int64
# stats.RecentResult.ItemData.AP                              int64
# stats.RecentResult.ItemData.Tank                            int64
# stats.RecentResult.avg_similarity                         float64
# stats.RecentResult.board_strength_percentile_sum            int64
# stats.RecentResult.damage_percentile_sum                    int64
# stats.RecentResult.lpChange                                 int64
# stats.RecentResult.num_played                               int64
# stats.RecentResult.percentile_count                         int64
# stats.RecentResult.place_sum                                int64
# stats.RecentResult.topCarries                              object
# stats.RecentResult.wins                                     int64
# stats.appMatches                                             bool
# stats.currentPatchResult.ItemData.AD                        int64
# stats.currentPatchResult.ItemData.AP                        int64
# stats.currentPatchResult.ItemData.Tank                      int64
# stats.currentPatchResult.avg_similarity                   float64
# stats.currentPatchResult.board_strength_percentile_sum    float64
# stats.currentPatchResult.damage_percentile_sum            float64
# stats.currentPatchResult.lpChange                         float64
# stats.currentPatchResult.num_played                         int64
# stats.currentPatchResult.percentile_count                   int64
# stats.currentPatchResult.place_sum                          int64
# stats.currentPatchResult.topCarries                        object
# stats.currentPatchResult.wins                               int64
# stats.num_played                                            int64
# stats.place_sum                                             int64
# stats.wins                                                  int64
# dtype: object

# %%
# Xử lý giá trị thiếu

# 1. Điền 0 cho các cột số nguyên có giá trị thiếu
numeric_cols = df_clean.select_dtypes(include=['int64', 'float64']).columns
for col in numeric_cols:
    if df_clean[col].isnull().sum() > 0:
        df_clean[col] = df_clean[col].fillna(0)

# 2. Điền chuỗi rỗng cho các cột string có giá trị thiếu  
string_cols = df_clean.select_dtypes(include=['object']).columns
for col in string_cols:
    if df_clean[col].isnull().sum() > 0:
        # Nếu là cột topCarries, điền []
        if 'topCarries' in col:
            df_clean[col] = df_clean[col].fillna('[]')
        else:
            df_clean[col] = df_clean[col].fillna('')

# 3. Xử lý đặc biệt cho cột 'live' (có thể có nhiều missing vì người chơi không online)
live_columns = [col for col in df_clean.columns if col.startswith('live.')]
for col in live_columns:
    if df_clean[col].isnull().sum() > 0:
        df_clean[col] = df_clean[col].fillna('')

print("✓ Đã xử lý giá trị thiếu")
print(f"\nKiểm tra lại giá trị thiếu:")
print(f"Tổng số giá trị thiếu: {df_clean.isnull().sum().sum()}")

if df_clean.isnull().sum().sum() > 0:
    print("\nCác cột vẫn còn giá trị thiếu:")
    print(df_clean.isnull().sum()[df_clean.isnull().sum() > 0])
else:
    print("✓ Không còn giá trị thiếu!")
# Out:
# ✓ Đã xử lý giá trị thiếu
#
# Kiểm tra lại giá trị thiếu:
# Tổng số giá trị thiếu: 0
# ✓ Không còn giá trị thiếu!

# %%
# Tóm tắt dữ liệu sau khi làm sạch
print("=== THỐNG KÊ DỮ LIỆU SAU KHI LÀM SẠCH ===\n")
print(f"Số dòng: {len(df_clean)}")
print(f"Số cột: {len(df_clean.columns)}")
print(f"Tổng giá trị thiếu: {df_clean.isnull().sum().sum()}")

print("\n=== THỐNG KÊ MÔ TẢ CÁC CỘT CHÍNH ===")
main_cols = ['rank', 'rating_numeric', 'num_played', 'stats.num_played', 'stats.wins']
existing_main_cols = [col for col in main_cols if col in df_clean.columns]
print(df_clean[existing_main_cols].describe())

print("\n=== MẪU DỮ LIỆU ===")
df_clean.head()
# Out:
# === THỐNG KÊ DỮ LIỆU SAU KHI LÀM SẠCH ===
#
# Số dòng: 1000
# Số cột: 41
# Tổng giá trị thiếu: 0
#
# === THỐNG KÊ MÔ TẢ CÁC CỘT CHÍNH ===
#               rank  rating_numeric   num_played  stats.num_played  stats.wins
# count  1000.000000     1000.000000  1000.000000       1000.000000   1000.0000
# mean    500.500000     4051.887000   607.092000        607.022000     98.9020
# std     288.819436      150.670009   272.230772        272.196834     42.8847
# min       1.000000     3897.000000   129.000000        129.000000     28.0000
# 25%     250.750000     3944.750000   404.750000        404.750000     67.7500
# 50%     500.500000     4005.000000   572.000000        572.000000     92.0000
# 75%     750.250000     4109.000000   748.000000        748.000000    120.0000
# max    1000.000000     4872.000000  1988.000000       1988.000000    351.0000
#
# === MẪU DỮ LIỆU ===
#    rank  rating_numeric  num_played  player_id summoner_region  \
# 0     1            4872         561  353582905             me1
# 1     2            4871         477    3941714             br1
# 2     3            4737         507    1696341            eun1
# 3     4            4735         477  450383412             sg2
# 4     5            4670         688    3322631             la2
#
#           riot_id                                              puuid  \
# 0       منجة#بحبك  SBM-65J8LDsup6NqXNrraEppoDoHt_QkPlA2qicbM_wQhT...
# 1   KBM Toddy#tft  nx9yc2rDqX_Rc7xwa7hJXeLZSQ5vCK6xMo9E8jDA9KQN1G...
# 2      Litiq#EUNE  h-oGE9-A_UbLbAn4r2Mhw0RST6V2otlLfuMihFFRXsyEOa...
# 3     FuuTime#xdd  dfFZTGk0bBYppTBlPNMvwrfsLwpsJF9vgl53-jjWxG4Kjm...
# 4  BlackSheep#Rap  NiJyBETk-4MDyXRA7qWaK-mPTVeAIdEOQkHr8nH7ywb__m...
#
#                  rating live.encryption_key  live.game_start_time  ...  \
# 0  CHALLENGER I 2072 LP                                       0.0  ...
# 1  CHALLENGER I 2071 LP                                       0.0  ...
# 2  CHALLENGER I 1937 LP                                       0.0  ...
# 3  CHALLENGER I 1935 LP                                       0.0  ...
# 4  CHALLENGER I 1870 LP                                       0.0  ...
#
#   stats.currentPatchResult.damage_percentile_sum  \
# 0                                         1339.0
# 1                                            0.0
# 2                                            3.0
# 3                                          290.0
# 4                                            0.0
#
#    stats.currentPatchResult.lpChange stats.currentPatchResult.num_played  \
# 0                              280.0                                  22
# 1                                0.0                                   0
# 2                               10.0                                   1
# 3                               83.0                                   8
# 4                                0.0                                   0
#
#    stats.currentPatchResult.percentile_count  \
# 0                                         22
# 1                                          0
# 2                                          1
# 3                                          8
# 4                                          0
#
#    stats.currentPatchResult.place_sum  \
# 0                                  55
# 1                                   0
# 2                                   4
# 3                                  22
# 4                                   0
#
#                  stats.currentPatchResult.topCarries  \
# 0                                                 []
# 1                                                 []
# 2  [{"character_id": "TFT15_Samira", "count": 1, ...
# 3                                                 []
# 4                                                 []
#
#    stats.currentPatchResult.wins  stats.num_played  stats.place_sum  \
# 0                              9               561             1983
# 1                              0               477             1576
# 2                              0               506             1732
# 3                              2               477             1711
# 4                              0               687             2206
#
#    stats.wins
# 0         109
# 1         120
# 2         119
# 3         121
# 4         211
#
# [5 rows x 41 columns]

# %%
# Lưu dữ liệu đã làm sạch
output_file = 'data/leaderboard_cleaned.csv'
df_clean.to_csv(output_file, index=False)

print(f"✓ Đã lưu dữ liệu đã làm sạch vào: {output_file}")
print(f"\nThông tin file:")
print(f"  - Số dòng: {len(df_clean)}")
print(f"  - Số cột: {len(df_clean.columns)}")
# Out:
# ✓ Đã lưu dữ liệu đã làm sạch vào: data/leaderboard_cleaned.csv
#
# Thông tin file:
#   - Số dòng: 1000
#   - Số cột: 41
